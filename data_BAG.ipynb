# %%
import pandas as pd
from zipfile import ZipFile
from bs4 import BeautifulSoup
import requests
import re, webbrowser
from urllib.request import urlopen
from io import BytesIO
import datetime 
import time

# %% [markdown]
# ### Getting Data from the Web

# %%
### Read file from BAG
link = "https://www.covid19.admin.ch/api/data/20210209-zyp7ir0s/downloads/sources-csv.zip"
resp = urlopen(link)
zipfile = ZipFile(BytesIO(resp.read()))

# %% [markdown]
# #### VaccDosesAdministered

# %%
fname = zipfile.namelist()[-4]
df_bag = pd.read_csv(zipfile.open(fname), dtype=object)

# %%
fname
# Out:
# 'data/COVID19VaccDosesAdministered.csv'

# %%
### Save BAG file local
TodaysDate = time.strftime("%d-%m-%Y")
excelfilename = "COVID19VaccDosesAdministered_" + TodaysDate +".xlsx"
excelfilename
df_bag.to_excel(r'BAG\\' + excelfilename)

# %%
### Prepare file for merge
df_bag.drop(df_bag.index[[-1,-2]], inplace = True)
df_bag = df_bag.rename(columns = {"sumTotal": "Total_Impfungen", "date": "Stand", "per100PersonsTotal": "Impfungen pro 100 Einwohner", "geoRegion": "Abk."})
df_bag["Stand"] = pd.to_datetime(df_bag["Stand"])
df_bag["Impfungen pro 100 Einwohner"] = pd.to_numeric(df_bag["Impfungen pro 100 Einwohner"]).astype(float)
df_bag["Total_Impfungen"] = pd.to_numeric(df_bag["Total_Impfungen"]).astype("int64")
df_bag.drop(columns = ["type", "pop","version"], inplace= True)

# %%
# Transform old data --> one time
df_vaccines = pd.read_excel("impf_daten.xlsx")
df_vaccines.head(10)
#df_vaccines= df_vaccines.sort_values(by = ["Abk.", "Stand"])
#df_vaccines= df_vaccines.fillna(method='ffill')
#df_vaccines["Impfungen pro 100 Einwohner"] = round(df_vaccines["Impfungen pro 100 Einwohner"], 1)
# Out:
#    Unnamed: 0  Unnamed: 0.1        Kanton Abk.  Total_Impfungen  Einwohner  \
# 0           0             0        Aargau   AG                0     685845
# 1           1             1        Aargau   AG            12100     685845
# 2           2             2        Aargau   AG            12973     685845
# 3           3             3        Aargau   AG            16730     685845
# 4           4             4        Aargau   AG            20034     685845
# 5           5            10        Aargau   AG            24812     685845
# 6           6             6  Appenzell-I.   AI                0      16128
# 7           7             7  Appenzell-I.   AI               40      16128
# 8           8             8  Appenzell-I.   AI              823      16128
# 9           9             9  Appenzell-I.   AI              917      16128
#
#    Impfungen pro 100 Einwohner      Stand      lat     lng
# 0                          0.0 2020-12-21  47.3923  8.0446
# 1                          1.8 2021-01-13  47.3923  8.0446
# 2                          1.9 2021-01-24  47.3923  8.0446
# 3                          2.4 2021-01-27  47.3923  8.0446
# 4                          2.9 2021-01-31  47.3923  8.0446
# 5                          3.6 2021-02-03  47.3923  8.0446
# 6                          0.0 2020-12-21  47.3162  9.4317
# 7                          0.2 2020-12-24  47.3162  9.4317
# 8                          5.1 2021-01-15  47.3162  9.4317
# 9                          5.7 2021-01-24  47.3162  9.4317

# %%
# Merge data and remove duplicates
m =pd.concat([df_vaccines, df_bag], axis = 0)
d = m.sort_values(by = ["Abk.", "Stand"])
dfcombined = d.fillna(method='ffill')
dfcombined["Impfungen pro 100 Einwohner"] = pd.to_numeric(dfcombined["Impfungen pro 100 Einwohner"]).fillna(0).astype(float)
dfcombined["Impfungen pro 100 Einwohner"] = round(dfcombined["Impfungen pro 100 Einwohner"], 1)
dfcombined.reset_index(drop=True, inplace=True)
dfcombined =dfcombined.drop_duplicates()

# %%
dfcombined.head(20)
# Out:
#     Unnamed: 0        Kanton Abk.  Total_Impfungen  Einwohner  \
# 0            0        Aargau   AG                0   685845.0
# 1            1        Aargau   AG            12100   685845.0
# 2            2        Aargau   AG            12973   685845.0
# 3            3        Aargau   AG            16730   685845.0
# 4            4        Aargau   AG            20034   685845.0
# 5           10        Aargau   AG            24812   685845.0
# 6            6  Appenzell-I.   AI                0    16128.0
# 7            7  Appenzell-I.   AI               40    16128.0
# 8            8  Appenzell-I.   AI              823    16128.0
# 9            9  Appenzell-I.   AI              917    16128.0
# 10          10  Appenzell-I.   AI             1077    16128.0
# 11          11  Appenzell-I.   AI             1092    16128.0
# 12          15  Appenzell-I.   AI             1395    16128.0
# 13          13  Appenzell-A.   AR                0    55445.0
# 14          14  Appenzell-A.   AR             1718    55445.0
# 15          15  Appenzell-A.   AR             2349    55445.0
# 16          16  Appenzell-A.   AR             2787    55445.0
# 17          17  Appenzell-A.   AR             3542    55445.0
# 18          14  Appenzell-A.   AR             3562    55445.0
# 19          19          Bern   BE                0  1039474.0
#
#     Impfungen pro 100 Einwohner      Stand      lat     lng
# 0                           0.0 2020-12-21  47.3923  8.0446
# 1                           1.8 2021-01-13  47.3923  8.0446
# 2                           1.9 2021-01-24  47.3923  8.0446
# 3                           2.4 2021-01-27  47.3923  8.0446
# 4                           2.9 2021-01-31  47.3923  8.0446
# 5                           3.6 2021-02-03  47.3923  8.0446
# 6                           0.0 2020-12-21  47.3162  9.4317
# 7                           0.2 2020-12-24  47.3162  9.4317
# 8                           5.1 2021-01-15  47.3162  9.4317
# 9                           5.7 2021-01-24  47.3162  9.4317
# 10                          6.7 2021-01-27  47.3162  9.4317
# 11                          6.8 2021-01-31  47.3162  9.4317
# 12                          8.6 2021-02-03  47.3162  9.4317
# 13                          0.0 2020-12-21  47.3665  9.3001
# 14                          3.1 2021-01-21  47.3665  9.3001
# 15                          4.2 2021-01-24  47.3665  9.3001
# 16                          5.0 2021-01-27  47.3665  9.3001
# 17                          6.4 2021-01-31  47.3665  9.3001
# 18                          6.4 2021-02-03  47.3665  9.3001
# 19                          0.0 2020-12-21  46.9480  7.4474

# %%
#Write impf data
dfcombined.to_excel("impf_daten.xlsx")

# %% [markdown]
# #### VaccDosesDelivered

# %%
fname = zipfile.namelist()[-3]
df_deliv = pd.read_csv(zipfile.open(fname), dtype=object)
fname
# Out:
# 'data/COVID19VaccDosesDelivered.csv'

# %%
df_deliv
# Out:
#    geoRegion        date      pop sumTotal per100PersonsTotal  \
# 0         GE  2021-01-31   504128    28050               5.56
# 1         VD  2021-01-31   805098    43425               5.39
# 2         VS  2021-01-31   345525    20975               6.07
# 3         FR  2021-01-31   321783    17325               5.38
# 4         NE  2021-01-31   176496    12975               7.35
# 5         JU  2021-01-31    73584     5700               7.75
# 6         BE  2021-01-31  1039474    63050               6.07
# 7         SO  2021-01-31   275247    17325               6.29
# 8         BS  2021-01-31   195844    14550               7.43
# 9         BL  2021-01-31   289468    21150               7.31
# 10        AG  2021-01-31   685845    40650               5.93
# 11        ZH  2021-01-31  1539275    77375               5.03
# 12        SH  2021-01-31    82348     6000               7.29
# 13        TG  2021-01-31   279547    16050               5.74
# 14        AR  2021-01-31    55445     4325                7.8
# 15        AI  2021-01-31    16128     1375               8.53
# 16        SG  2021-01-31   510734    29250               5.73
# 17        GL  2021-01-31    40590     2950               7.27
# 18        SZ  2021-01-31   160480    10425                6.5
# 19        ZG  2021-01-31   127642     7575               5.93
# 20        LU  2021-01-31   413120    25875               6.26
# 21        NW  2021-01-31    43087     3925               9.11
# 22        OW  2021-01-31    37930     2850               7.51
# 23        UR  2021-01-31    36703     3825              10.42
# 24        GR  2021-01-31   199021    12900               6.48
# 25        TI  2021-01-31   351491    25975               7.39
# 26        FL  2021-01-31    38747     1775               4.58
# 27      CHFL  2021-01-31  8644780   517625               5.99
# 28        CH  2021-01-31  8606033   515850               5.99
#
#                          type              version
# 0   COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 1   COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 2   COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 3   COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 4   COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 5   COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 6   COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 7   COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 8   COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 9   COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 10  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 11  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 12  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 13  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 14  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 15  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 16  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 17  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 18  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 19  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 20  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 21  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 22  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 23  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 24  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 25  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 26  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 27  COVID19VaccDosesDelivered  2021-01-31_18-00-00
# 28  COVID19VaccDosesDelivered  2021-01-31_18-00-00

# %% [markdown]
# #### Owid data

# %%
df_owid = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/Switzerland.csv")

# %%
df_owid
# Out:
#       location        date                   vaccine  \
# 0  Switzerland  2020-12-23           Pfizer/BioNTech
# 1  Switzerland  2021-01-14           Pfizer/BioNTech
# 2  Switzerland  2021-01-19           Pfizer/BioNTech
# 3  Switzerland  2021-01-21           Pfizer/BioNTech
# 4  Switzerland  2021-01-24           Pfizer/BioNTech
# 5  Switzerland  2021-01-29  Moderna, Pfizer/BioNTech
# 6  Switzerland  2021-01-31  Moderna, Pfizer/BioNTech
#
#                                           source_url  total_vaccinations  \
# 0  https://www.nytimes.com/2020/12/23/world/switz...                   0
# 1  https://twitter.com/srfnews/status/13497272413...               66000
# 2  https://www.srf.ch/news/schweiz/das-neueste-zu...              110000
# 3  https://www.bag.admin.ch/dam/bag/fr/dokumente/...              169783
# 4  https://www.bag.admin.ch/dam/bag/fr/dokumente/...              197368
# 5  https://www.bag.admin.ch/dam/bag/fr/dokumente/...              262081
# 6  https://www.covid19.admin.ch/en/epidemiologic/...              315033
#
#    people_vaccinated  people_fully_vaccinated
# 0                NaN                      NaN
# 1                NaN                      NaN
# 2                NaN                      NaN
# 3                NaN                      NaN
# 4                NaN                      NaN
# 5                NaN                      NaN
# 6                NaN                      NaN
